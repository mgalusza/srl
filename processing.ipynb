# %%
# !pip3 install --user matplotlib
# !pip3 install ipywidgets
# Out:
# Requirement already satisfied: matplotlib in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (3.5.3)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Python/3.7/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in /Library/Python/3.7/site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: cycler>=0.10 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.12.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /Library/Python/3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (3.10.0.2)
# You are using pip version 19.0.3, however version 23.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: ipywidgets in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (8.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipywidgets) (6.16.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipywidgets) (4.0.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipywidgets) (3.0.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipywidgets) (5.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: packaging in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: nest-asyncio in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.3)
# Requirement already satisfied: psutil in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.2)
# Requirement already satisfied: pyzmq>=17 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets) (40.8.0)
# Requirement already satisfied: backcall in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.31)
# Requirement already satisfied: decorator in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mgalusza/Library/Python/3.7/lib/python/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.12.0)
# You are using pip version 19.0.3, however version 23.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip3 install --user jsonnet==0.17.0
# !pip3 install --user allennlp==2.1.0 allennlp-models==2.1.0

# %% [markdown]
# from allennlp.predictors.predictor import Predictor
#
# model_url = "https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2021.03.10.tar.gz"
# predictor_coref = Predictor.from_path(model_url)  # load the model

# %%
text = """
Iraqi Vice President Taha Yassin Ramadan announced today, Sunday, that Iraq refuses to back down from its decision to stop cooperating with disarmament inspectors before its demands are met. 
Iraqi Vice president Taha Yassin Ramadan announced today, Thursday, that Iraq rejects cooperating with the United Nations except on the issue of lifting the blockade imposed upon it since the year 1990. 
Ramadan told reporters in Baghdad that ”Iraq cannot deal positively with whoever represents the Security Council unless there was a clear stance on the issue of lifting the blockade off of it. 
Baghdad had decided late last October to completely cease cooperating with the inspectors of the United Nations Special Commission UNSCOM in charge of disarming Iraq’s weapons, and whose work became very limited since the fifth of August, and announced it will not resume its cooperation with the Commission even if it were subjected to a military operation. 
The Russian Foreign Minister, Igor Ivanov, warned today, Wednesday against using force against Iraq, which will destroy, according to him, seven years of difficult diplomatic work and will complicate the regional situation in the area. 
Ivanov contended that carrying out air strikes against Iraq, who refuses to cooperate with the United Nations inspectors, “will end the tremendous work achieved by the international group during the past seven years and will complicate the situation in the region.” 
Nevertheless, Ivanov stressed that Baghdad must resume working with the Special Commission in charge of disarming the Iraqi weapons of mass destruction (UNSCOM). 
The Special Representative of the United Nations Secretary-General in Baghdad, Prakash Shah, announced today, Wednesday, after meeting with the Iraqi Deputy Prime Minister Tariq Aziz, that Iraq refuses to back down from its decision to cut off cooperation with the disarmament inspectors. 
British Prime Minister Tony Blair said today, Sunday, that the crisis between the international community and Iraq “did not end” and that Britain is still “ready, prepared, and able to strike Iraq.” 
In a gathering with the press held at the Prime Minister’s office, Blair contended that the crisis with Iraq “will not end until Iraq has absolutely and unconditionally respected its commitments” towards the United Nations. 
A spokesman for Tony Blair had indicated that the British Prime Minister gave permission to British Air Force Tornado planes stationed in Kuwait to join the aerial bombardment against Iraq.
"""

# %%
text  = """Teton Canyon ends about six miles below the dam site, where the river flows onto the Snake River Plain. 
When the dam failed, the flood struck several communities immediately downstream, particularly Wilford at the terminus of the canyon, Sugar City, Salem, Hibbard, and Rexburg. 
Thousands of homes and businesses were destroyed.
The small agricultural communities of Wilford and Sugar City were wiped from the river bank. 
Five of the eleven deaths attributed to the flood occurred in Wilford. 
The similar community of Teton, on the south bank of the river, is on a modest bench and was largely spared.
One Teton resident was fishing on the river at the time of the dam failure and was drowned. 
An elderly woman living in the city of Teton died as a result of the evacuation.
One estimate placed damage to Hibbard and Rexburg area, with a population of about 10,000, at 80% of existing structures. 
The Teton River flows through the industrial, commercial, and residential districts of north Rexburg. 
A significant reason for the massive damage in the community was the location of a lumber yard directly upstream.   
When the flood waters hit, thousands of logs were washed into town. 
Dozens of logs hit a bulk gasoline-storage tank a few hundred yards away. 
The gasoline ignited and sent flaming slicks adrift on the racing water.
The force of the logs and cut lumber and the subsequent fires practically destroyed the city.
The flood waters traveled west along the route of the Henrys Fork of the Snake River, around both sides of the Menan Buttes, significantly damaging the community of Roberts. 
The city of Idaho Falls, even further down on the flood plain, had time to prepare.
At the older American Falls Dam downstream, engineers increased discharge by less than 5% before the flood arrived.
That dam held and the flood was effectively over, but tens of thousands of acres of land near the river were stripped of fertile topsoil.
The force of the failure destroyed the lower part of the Teton River, washing away riparian zones and reducing the canyon walls.
This seriously damaged the stream's ecology and impacted the native Yellowstone cutthroat trout population. 
The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries, as far downstream as the Fort Hall bottoms.

In August 1975, the region experienced an extreme flood, resulting in quantities of water falling that had not been considered during the construction of the dam.
More than a year's worth of rain fell in only 24 hours, and the dam failed on August 8. 
Early on August 8, the dam was breached and 700 million cubic meters of floodwater was released, flooding communities and homes downstream. 
After this burst, a chain reaction began and the other 61 reservoirs located in the area collapsed—releasing another six billion cubic meters of floodwater. 
The water covered an area equal to 10 000 square kilometers. 
The failure to plan and account for extreme floodwaters resulted in the immediate death of 26 000 as a result of the water itself. 
145 000 more people died as a result of epidemics and famine following the flood.
The cause of the incident was reported to be unsafe vibrations coming from one of the turbines, which caused the turbine to break apart violently. 
Water that had been entering the turbine, flooded the turbine hall—flooding the room and levels below. 
The ceiling of the hall also broke apart from the impact from the turbine. 
At this point, power failed in the power station resulting in a blackout. 
Gasoline can cause fires.
Steel gates to the water intake pipes of the turbines were manually closed and spillways were opened to prevent more damage.
"""

# %%
text = """
During cruising the temperature of the fuel in the fuel tank decreases to a very low temperature as the pressure in the upper atmosphere.
So, it becomes an area of heightened importance that jet fuel be free from water contamination. 
The water particles in the fuel causes precipitation and deteriorate the combustion process. 
The separated water then drops to the bottom of the tank, because it is denser than the fuel. 
Since the water is no longer in solution, it can form droplets which can supercool to below 0 °C. 
If these supercooled droplets collide with a surface they can freeze and may result in blocked fuel inlet pipes and may be a cause of the flight accidents as in the case of British Airways Flight 38. 
Removing all water from fuel is impractical; therefore, fuel heaters are usually used on commercial aircraft to prevent water in fuel from freezing.
"""

# %%
sents = text.split(".")

# %%
def removePunctation(sent):
    return sent.replace(',',' ').replace('’s','s').replace(':',' ').replace(';',' ').replace(':','.').replace("!",".").replace("?",".").replace(".","").replace('-',' ').replace('(',' ').replace(')',' ').replace('  ',' ').strip().strip('\n')

# %%
sents_no_punct = []
for s in sents:
    sents_no_punct.append(removePunctation(s))

# %%
len(sents_no_punct)
# Out:
# 36

# %%
import networkx as nx
import pandas as pd
import networkx as nx
import itertools
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
from allennlp.predictors.predictor import Predictor
import allennlp_models.tagging
s = sents_no_punct[3]

predictor_srl = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz")
r = predictor_srl.predict(
    sentence=s
)

# %%
from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib as mpl
import matplotlib.pyplot as plt

def drawgraph2(graph, density=False):
  ## insert the graph you just converted from the edge list
  ## the default for the density is False. If density = True, it will return the density of the graph
  edges,weights = zip(*nx.get_edge_attributes(graph,'weight').items()) ## extract the edges and weights for later use
  ## k will affect the optimal distance between nodes.
  ## more types of layouts can be found at https://networkx.org/documentation/stable/reference/drawing.html
  pos=nx.spring_layout(graph,k=0.05,seed=42)
  edge_labels = dict([((n1, n2), d['label'])
                    for n1, n2, d in graph.edges(data=True)])
  nx.draw_networkx(graph,
                   pos,
                  # with_labels=True,
                  # node_size=400,
                  # node_color="mistyrose",
                  # edgelist=edges, 
                  # edge_color=weights,
                   edge_cmap=plt.cm.Blues_r,
                   edge_labels=edge_labels,
                   style="solid",
                   width=1)
  plt.subplots_adjust(left=2, bottom=3.2, right=6, top=6)
  if density:
        print("----------------------------------------")
        print("Density:",nx.classes.function.density(graph))
        print("----------------------------------------")
  return plt.show()

# %%
def drawgraph(graph, density=False):
  ## insert the graph you just converted from the edge list
  ## the default for the density is False. If density = True, it will return the density of the graph
  edges,weights = zip(*nx.get_edge_attributes(graph,'weight').items()) ## extract the edges and weights for later use
  ## k will affect the optimal distance between nodes.
  ## more types of layouts can be found at https://networkx.org/documentation/stable/reference/drawing.html
  pos=nx.spring_layout(graph,k=0.05,seed=42)
  nx.draw_networkx(graph,
                   pos,
                   with_labels=True,
                   node_size=400,
                   node_color="mistyrose",
                   edgelist=edges, 
                   edge_color=weights,
                   edge_cmap=plt.cm.Blues_r,
                   style="solid",
                   width=1)
  plt.subplots_adjust(left=2, bottom=3.2, right=6, top=6)
  if density:
        print("----------------------------------------")
        print("Density:",nx.classes.function.density(graph))
        print("----------------------------------------")
  return plt.show()

# %%
import hashlib

def parseSRLPredictor3(sent,s_id):
        ret = []
        srl = predictor_srl.predict(sentence=sent)
        size = len(srl['verbs'])
        pos_1 = nlp(sent)
        for j in range(0,size):
                frame_v = srl['verbs'][j]
                #srl_struct = parseSRLPredictor5(sent,frame_v,s_id)
               # print(j)
               # print(frame_v['verb'])
               # print(frame_v['description'])
               # print(frame_v['tags'])
                s_tags = len(frame_v['tags'])
                pos = []
                words = []
                tags = []
                lemma = []
                nouns = []
                verbs = []
                centers = []
                frame_txt = ''
                v_s = 0
                v = ''
                other_tags_cnt = 0
                for i in range(0,s_tags):
                        if frame_v['tags'][i] != 'O':
                                frame_txt = frame_txt + ' ' + str(pos_1[i]).strip()
                                if pos_1[i].pos_ == 'VERB':
                                        v_s = v_s + 1
                                if pos_1[i].pos_ in ('NOUN','PROPN'):
                                        nouns.append(str(pos_1[i]).strip())
                                        if clearTag(frame_v['tags'][i]) in ('ARG0', 'ARG1','ARG2'):
                                                centers = centers + [str(pos_1[i].lemma_).strip()]
                                pos.append(pos_1[i].pos_)
                                words.append((str(pos_1[i]).strip()))
                                lemma.append((str(pos_1[i].lemma_).strip()))
                                tags.append(clearTag(frame_v['tags'][i]))
                                if frame_v['tags'][i] == 'B-V':
                                        v = str(pos_1[i]).strip()
                                if frame_v['tags'][i] != 'B-V':
                                        other_tags_cnt = other_tags_cnt + 1
                                if pos_1[i].pos_ == 'VERB':
                                        if frame_v['tags'][i] != 'B-V':
                                                verbs.append(str(pos_1[i]).strip())
                                        

               # print(pos)
               # print(words)
               # print(tags)
                #tags = srl['verbs'][j]['tags']
                #pos_1 = nlp(sent)
                #ret = []
                #size2 = len(tags)
                #ret.append(frame_v)
                #for i in range(0,size):
          #  try:
                #        if tags[i]!='O':
                #                ret.append((s_id,j,frame_v,str(pos_1[i]).strip(),tags[i][2:],str(pos_1[i].lemma_).strip(),str(pos_1[i].pos_)))
                if v_s != 0:
                        encoded = frame_txt.encode()
                        result = str(hashlib.sha256(encoded).hexdigest())
                        ret.append((frame_v['description'],words,pos,lemma, tags,v_s,v,s_id,nouns,verbs,frame_txt.strip(),result,centers))
        return ret

# %%
def getNounsForVerb(pd,verb):
    s = set()
    x = pd[pd.verb == verb]['nouns'].values 
    if len(x)>0: 
        return set(x[0])
    return set()

# %%
def parseSentence(G,sent,s_id):

    ret = parseSRLPredictor3(sent,s_id)
    ret_pd = pd.DataFrame(ret,columns=['description','words','pos','lemma','role','verbs_cnt','verb','s_id','nouns','verbs','frame_txt','frame_id','centers'])
    ret_pd.sort_values('verbs_cnt',inplace=True)
    for index, row in ret_pd.iterrows():
        verb_node = (row['verb'],'verb',s_id)
        frame_txt = row['frame_txt']
        frame_id  = row['frame_id']
        centers = row['centers']
        role = row['role']
        G.add_node(verb_node,frame=frame_txt,frame_id = frame_id, centering_nouns = centers,labels = ':VERB')
        print("verb")
        print(verb_node)
        node_type = 'START'
        role = row['role']
        words = row['words']
        lemma = row['lemma']
        pos = row['pos']
        nouns = []
        verb_nouns = set()
        verbs = []
        node_txt = ''
        for i in range(0,len(role)):
            if role[i]!='O' and role[i]!='V':
                if role[i] != node_type:
                    if node_type == 'START':
                        node_type = role[i]
                        node_txt = words[i]
                        nouns = []
                        verbs = []
                        if pos[i] in ('NOUN',"PROPN"):
                            nouns = [lemma[i]]
                        if pos[i] == 'VERB':
                            verbs = [words[i]]
                        
                    elif node_txt != '':
                        srl_node = (node_txt,'role',s_id)
                        G.add_node(srl_node,frame=frame_txt,frame_id = frame_id,centering_nouns = centers, role=node_type, labels = ':ROLE')
                        G.add_edge(verb_node,srl_node, weight = 1)


                        verb_nouns = set()
                        for v in verbs:
                            n_n = (v,'verb',s_id)
                            if not G.has_node(n_n):
                                G.add_node(n_n,frame='E',frame_id = '-1',centering_nouns = [], labels = ':VERB')
                            G.add_edge(n_n,srl_node, weight = 1)
                            verb_nouns = verb_nouns.union(getNounsForVerb(ret_pd,v))

                        set_nouns = set(nouns)
                        diff = set_nouns.difference(verb_nouns)
                        #if node_type in ('ARG0','ARG1'):                           
                        #     G.nodes[verb_node]['centering_nouns'] = centers

                        for n in diff:
                            n_n = (n,'noun')
                            G.add_node(n_n,frame='EMPTY',frame_id = '-1',labels = ':NOUN')
                            G.add_edge(n_n,srl_node, weight = 1)

                        if pos[i] in ('NOUN',"PROPN"):
                            nouns = [lemma[i]]
                        else:
                            nouns = []
                        if pos[i] == 'VERB':
                            verbs = [words[i]]
                        else:
                            verbs = []

                        node_txt = words[i]
                        node_type = role[i]
                else:

                    node_txt = node_txt + ' ' + words[i]
                    if pos[i] in ('NOUN',"PROPN"):
                        nouns.append(lemma[i])
                    if pos[i] == 'VERB':
                        verbs.append(words[i])
        if node_txt != '':
            srl_node = (node_txt,'role',s_id)
            G.add_node(srl_node,frame=frame_txt,frame_id = frame_id,centering_nouns = centers,role=node_type,labels = ':ROLE')
            if node_type in ('ARG0','ARG1'):                           
                G.nodes[verb_node]['centering_nouns'] = nouns
            G.add_edge(verb_node,srl_node, weight = 1)
            verb_nouns = set()
            for v in verbs:
                n_n = (v,'verb',s_id)
                if not G.has_node(n_n):
                    G.add_node(n_n,frame='E',frame_id = '-1',centering_nouns = [],labels = ':VERB')
                G.add_edge(n_n,srl_node, weight = 1)
                verb_nouns = verb_nouns.union(getNounsForVerb(ret_pd,v))
            set_nouns = set(nouns)
            for n in set_nouns.difference(verb_nouns):
                n_n = (n,'noun')
                G.add_node(n_n,frame='EMPTY',frame_id = '-1',labels = ':NOUN')
                G.add_edge(n_n,srl_node, weight = 1)

    return G

# %%
G = nx.Graph()
s_id = 0
for s in sents_no_punct:
    G = parseSentence(G,s,s_id)
    s_id = s_id + 1
# Out:
# verb
# ('flows', 'verb', 0)
# verb
# ('ends', 'verb', 0)
# verb
# ('failed', 'verb', 1)
# verb
# ('downstream', 'verb', 1)
# verb
# ('struck', 'verb', 1)
# verb
# ('destroyed', 'verb', 2)
# verb
# ('wiped', 'verb', 3)
# verb
# ('attributed', 'verb', 4)
# verb
# ('occurred', 'verb', 4)
# verb
# ('spared', 'verb', 5)
# verb
# ('fishing', 'verb', 6)
# verb
# ('was', 'verb', 6)
# verb
# ('drowned', 'verb', 6)
# verb
# ('living', 'verb', 7)
# verb
# ('died', 'verb', 7)
# verb
# ('existing', 'verb', 8)
# verb
# ('placed', 'verb', 8)
# verb
# ('flows', 'verb', 9)
# verb
# ('hit', 'verb', 11)
# verb
# ('washed', 'verb', 11)
# verb
# ('hit', 'verb', 12)
# verb
# ('ignited', 'verb', 13)
# verb
# ('sent', 'verb', 13)
# verb
# ('cut', 'verb', 14)
# verb
# ('destroyed', 'verb', 14)
# verb
# ('damaging', 'verb', 15)
# verb
# ('traveled', 'verb', 15)
# verb
# ('prepare', 'verb', 16)
# verb
# ('had', 'verb', 16)
# verb
# ('arrived', 'verb', 17)
# verb
# ('increased', 'verb', 17)
# verb
# ('held', 'verb', 18)
# verb
# ('stripped', 'verb', 18)
# verb
# ('washing', 'verb', 19)
# verb
# ('reducing', 'verb', 19)
# verb
# ('destroyed', 'verb', 19)
# verb
# ('damaged', 'verb', 20)
# verb
# ('impacted', 'verb', 20)
# verb
# ('damaged', 'verb', 21)
# verb
# ('considered', 'verb', 22)
# verb
# ('falling', 'verb', 22)
# verb
# ('resulting', 'verb', 22)
# verb
# ('experienced', 'verb', 22)
# verb
# ('fell', 'verb', 23)
# verb
# ('failed', 'verb', 23)
# verb
# ('breached', 'verb', 24)
# verb
# ('released', 'verb', 24)
# verb
# ('burst', 'verb', 25)
# verb
# ('located', 'verb', 25)
# verb
# ('releasing', 'verb', 25)
# verb
# ('began', 'verb', 25)
# verb
# ('collapsed', 'verb', 25)
# verb
# ('covered', 'verb', 26)
# verb
# ('plan', 'verb', 27)
# verb
# ('resulted', 'verb', 27)
# verb
# ('following', 'verb', 28)
# verb
# ('died', 'verb', 28)
# verb
# ('break', 'verb', 29)
# verb
# ('coming', 'verb', 29)
# verb
# ('caused', 'verb', 29)
# verb
# ('be', 'verb', 29)
# verb
# ('reported', 'verb', 29)
# verb
# ('entering', 'verb', 30)
# verb
# ('flooding', 'verb', 30)
# verb
# ('flooded', 'verb', 30)
# verb
# ('broke', 'verb', 31)
# verb
# ('resulting', 'verb', 32)
# verb
# ('failed', 'verb', 32)
# verb
# ('cause', 'verb', 33)
# verb
# ('closed', 'verb', 34)
# verb
# ('prevent', 'verb', 34)
# verb
# ('opened', 'verb', 34)

# %%
G_ego = nx.ego_graph(G,('city','noun'),radius=4)
drawgraph(G_ego)

# %%
from transformers import BartForSequenceClassification, BartTokenizer
bart_tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-mnli')
bart_model = BartForSequenceClassification.from_pretrained('facebook/bart-large-mnli')
# Out:
# Some weights of the model checkpoint at facebook/bart-large-mnli were not used when initializing BartForSequenceClassification: ['model.encoder.version', 'model.decoder.version']
# - This IS expected if you are initializing BartForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # from transformers import pipeline
# classifier = pipeline("zero-shot-classification",
#                        model="facebook/bart-large-mnli")
#
# import numpy as np
# def getContinuationBertOld(s_s,s_t):
#     try:
#         if s_t is None:
#             return 0
#         ret = np.asarray(classifier(s_s, s_t,multi_class=True)['scores'])
#         ones = np.ones(len(s_t))
#         return np.average(ones-ret)
#     except Exception as e:
#         print(e)
#         return 100

# %%
#from transformers import pipeline
#classifier = pipeline("zero-shot-classification",
                       #model="facebook/bart-large-mnli")

import numpy as np
from numpy import dot
from numpy.linalg import norm

import allennlp_models
from allennlp.predictors.predictor import Predictor
from transformers import AutoModelForSequenceClassification, AutoTokenizer

import requests

BART_URL = "https://api-inference.huggingface.co/models/facebook/bart-large-mnli"
RTE_URL = "https://api-inference.huggingface.co/models/HiTZ/A2T_RoBERTa_SMFA_TACRED-re"
SIM_URL = "https://api-inference.huggingface.co/models/sentence-transformers/all-MiniLM-L6-v2"
headers = {"Authorization": "Bearer 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"}

#RTE_predictor = Predictor.from_path("decomposable-attention-elmo-2020.04.09.tar.gz")

nli_model = AutoModelForSequenceClassification.from_pretrained('facebook/bart-large-mnli')
nli_tokenizer = AutoTokenizer.from_pretrained('facebook/bart-large-mnli')

def query(URL, payload):
	response = requests.post(URL, headers=headers, json=payload)
	return response.json()

def getContinuationBert(source_frame, source_centering,target_frame):
    try:
        if source_centering is None:
            return 0
        if len(source_centering)<1:
            return 0
        source_output = query(BART_URL,{
                    "inputs": source_frame,
                    "parameters": {"candidate_labels": source_centering,"multi_label":True},
        })
        s = sorted(list(zip(source_output['labels'],source_output['scores'])),key=lambda tup: tup[0])

        target_output = query(BART_URL,{
                    "inputs": target_frame,
                    "parameters": {"candidate_labels": source_centering,"multi_label":True},
        })

        t = sorted(list(zip(target_output['labels'],target_output['scores'])),key=lambda tup: tup[0])

        
        n = len(s)
        s_v = []
        t_v = []
        r = 0
 
        for i in range(0,n):
        #    s_v = s_v + [s[i][1]]
        #    t_v = t_v + [t[i][1]]
             if s[i][1] > t[i][1]:
                r = r + 1
             else:
                r = r + s[i][1]/t[i][1]

        #for i in range(0,n):
        #    r = r + s_v[i]
        #    if t[i][1] < s[i][1]:
        #       ret = ret + t[i][1]/s[i][1]
        #    else:
        #        ret = ret + s[i][1]
        #return ret/n
       # print(s_v)
       # print(t_v)
       # if n > 1:
       #     return dot(s_v, t_v)/len(s_v)
       # else:
       #     return s_v[0]*t_v[0]
       # print(r)
        return r/n
    except Exception as e:
        print(e)
        print(source_frame)
        print(source_centering)
        print(target_frame)
        return 0

def getContinuationBert2(source_frame, target_frame,source_noun, target_noun):
    try:
        Ay = query(BART_URL,{
                    "inputs": source_frame,
                    "parameters": {"candidate_labels": target_noun,"multi_label":True},
        })['scores'][0]

        print(Ay)
        Bx = query(BART_URL,{
                    "inputs": target_frame,
                    "parameters": {"candidate_labels": source_noun,"multi_label":True},
        })['scores'][0]
        
        print(Bx)
        AB = source_frame + "." + target_frame 
        ABx = query(BART_URL,{
                    "inputs": AB,
                    "parameters": {"candidate_labels": source_noun,"multi_label":True},
        })['scores'][0]

        ABy = query(BART_URL,{
                    "inputs": AB,
                    "parameters": {"candidate_labels": target_noun,"multi_label":True},
        })['scores'][0]

        return Ay*Bx/(ABx*ABy)

    except Exception as e:
        print(e)
        return 0

def getZeroShotClassification(sent, tags_positive, tags_negative):
    try:
        if sent is None:
            return 0
        output = query(BART_URL,{
                    "inputs": sent,
                    "parameters": {"candidate_labels":tags_positive,"multi_label":True},
        })
        pos_output = np.array(output['scores'])

        output = query(BART_URL,{
                    "inputs": sent,
                    "parameters": {"candidate_labels":tags_negative,"multi_label":True},
        })

        neg_output = np.array(output['scores'])
        return pos_output-neg_output
  

        return (pos_output,neg_output, dist_pos, dist_neg, dist)

    except Exception as e:
        print(e)
        return 0

def getRTE(s_s,s_t):
    try:
        if s_t is None:
            return 0
        output = query(RTE_URL,{
                    "inputs": s_s,
                    "parameters": {"candidate_labels": s_t},
        })
        ret = np.asarray(output['scores'])
        ones = np.ones(len(s_t))
        return ret[0]
    except Exception as e:
        print(e)
        return 1

def getRTE2(s_s, s_t):
    try:
        if s_t is None:
            return 0
    

    # pose sequence as a NLI premise and label (politics) as a hypothesis
        premise = s_s
        hypothesis = s_t

    # run through model pre-trained on MNLI
        x = nli_tokenizer.encode(premise, hypothesis, return_tensors='pt')
        logits = nli_model(x)[0]

        entail_logits = logits[:,[0,1,2]]
        probs = entail_logits.softmax(dim=1)
        prob_label_is_true = probs[:,2].tolist()[0]
        #return prob_label_is_true[0].item()
        return prob_label_is_true
    except Exception as e:
        print(e)
        return 0


#def getRTE3(s_s,s_t):

#   w = 1 - RTE_predictor.predict(premise=s_s, hypothesis=s_t)['label_probs'][1]

#    return w

def getSim(s_s, s_t):

    output = query(SIM_URL,{
                    "inputs": {
                         "source_sentence": s_s,
                    "sentences": [
                        s_t
                    ]
                    }
                } )

    return output[0]
# Out:
# Some weights of the model checkpoint at facebook/bart-large-mnli were not used when initializing BartForSequenceClassification: ['model.encoder.version', 'model.decoder.version']
# - This IS expected if you are initializing BartForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BartForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def find_path3(G,curr_node,e_node,visited,path,steps,n,meta_path,curr_step,v_label,th_fun,thrld,bidir=False):
    global paths
    global KG
      
    
    if curr_step == len(meta_path)-1:
        source_node = path[0]
        target_node = path[curr_step]
        if source_node != target_node:
                t = th_fun(G,path,meta_path,thrld)
                if t>thrld:
                    paths = paths + [path]
                    KG.add_edge(source_node,target_node,weight=t,label = v_label)
                    if bidir:
                        KG.add_edge(target_node_att,source_node_att,weight=t,label = v_label)
                return
    visited.add(curr_node)
    for neigh in G.neighbors(curr_node):
        if neigh not in visited and (neigh[1] == meta_path[curr_step+1]):
                if neigh[1]=='role':
                    #if G.nodes[neigh]['role'] in ('ARG0','ARG1','ARG2','ARG3','ARG4'):
                #        print('next')
                        find_path3(G,neigh,e_node,visited,path+[neigh],steps, n+1,meta_path,curr_step+1,v_label,th_fun,thrld,bidir)
                else:
                #        print('next')
                        find_path3(G,neigh,e_node,visited,path+[neigh],steps, n+1,meta_path,curr_step+1,v_label,th_fun,thrld,bidir)

    visited.remove(curr_node)

def start_path3(G,s_node, e_node,steps,meta_path,v_label,th_fun,thrld,bidir=False):
    global paths
    global KG
    paths = []
    find_path3(G,s_node,(),set(),[s_node],steps,10,meta_path,0,v_label,th_fun,thrld,bidir)
    return paths

# %%
def isSimilar(G,path,meta_path,thrld):
    # in this function noun starts and finishes. There are 2 different frames.
    try:
        source_frame = G.nodes[path[1]]['frame']
        target_frame = G.nodes[path[len(meta_path)-2]]['frame']
        target_centers = G.nodes[path[len(meta_path)-2]]['centering_nouns']
        if len(target_centers) > 0 :
            th = getContinuationBert(source_frame,target_centers,target_frame)
            return th
    except Exception as e:
        return 0.0

    return 0.0

def isEffect(G,path,meta_path,thrld):
    # in this function noun starts and finishes. There are 2 different frames.
    s_premise = set()
    premise = ""
    for e in path:
        if e[1] != 'noun':
            s_premise.add(G.nodes[e]['frame'])
    for e in s_premise:
        premise = premise + "." + e
    hypothesis = path[0][0] + ' has an effect on ' + path[len(meta_path)-1][0]
    t = getRTE2(premise,hypothesis)
    print("RTE")
    print(premise)
    print(hypothesis)
    print(t)
    if  t > thrld:
        return t
    return t


def isEffectSimiar(G,path,meta_path,thrld):
    try:
        if isSimilar(G,path,meta_path,thrld)>thrkd:
            if isEffect(G,path,meta_path,thrld)>thrkd:
                return thrkd
            else:
                return 0
    except Exception as e:
        return 0
    finally:
        return 0
    
def isDanger(G,path,meta_path,thrld):
    # in this function noun starts and finishes. There are 2 different frames.
     # in this function noun starts and finishes. There are 2 different frames.
    premise = G.nodes[path[1]]['frame'] 
    hypothesis = path[0][0] + ' causes danger to ' + path[len(meta_path)-1][0]
    t = getRTE2(premise,hypothesis)
    print("RTE")
    print(premise)
    print(hypothesis)
    print(t)
    if  t > thrld:
        return t
    return t

def isDefault(G,path,meta_path,thrld):
    # in this function noun starts and finishes. There are 2 different frames.
     # in this function noun starts and finishes. There are 2 different frames.
    
    return True

# %%
KG = nx.DiGraph()
meta_s1 = ['noun','role','verb','role','noun','role','verb','role','noun']
meta_s2 = ['noun','role','verb','role','noun','role','noun']
meta_e1 = ['noun','role','noun']
meta_e2 = ['noun','role','verb','role','noun']

#meta_s1 = ['role','verb','role','noun','role','verb','role']
#meta_v1 = ['verb','role','noun','role','verb',]
#meta_s2 = ['role','verb','role','noun','role']
#meta_e2 = ['role','verb','role']


start_node = ('log', 'noun')
G_3 = nx.ego_graph(G, start_node ,6)
drawgraph(G_3)

for n in G.nodes():
    if n[1] == 'noun':
            t_path = start_path3(G, n,(),12,meta_s1,'has_effect_on',isEffectSimiar,0.5)
            t_path = start_path3(G, n,(),12,meta_s2,'has_effect_on',isEffectSimiar,0.5)
            t_path = start_path3(G, n,(),12,meta_e1,'has_effect_on',isEffect,0.8)
            t_path = start_path3(G, n,(),12,meta_e2,'has_effect_on',isEffect,0.8)
# Out:
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# RTE
# .the dam site where the river flows onto the Snake River Plain
# site has an effect on dam
# 0.24911651015281677
# RTE
# .the dam site where the river flows onto the Snake River Plain
# site has an effect on river
# 0.5366106033325195
# RTE
# .the dam site where the river flows onto the Snake River Plain
# site has an effect on Plain
# 0.6019359230995178
# RTE
# .the dam site where the river flows onto the Snake River Plain
# site has an effect on Snake
# 0.4671840965747833
# RTE
# .the dam site where the river flows onto the Snake River Plain
# site has an effect on River
# 0.5209200978279114
# RTE
# .Teton Canyon ends about six miles below the dam site where the river flows onto the Snake River Plain.the dam site where the river flows onto the Snake River Plain
# site has an effect on mile
# 0.14036276936531067
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# quantities of water that not considered during the construction of the dam
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# RTE
# .the dam site where the river flows onto the Snake River Plain
# dam has an effect on site
# 0.36006462574005127
# RTE
# .One Teton resident fishing on the river at the time of the dam failure
# dam has an effect on time
# 0.06081452593207359
# RTE
# .One Teton resident fishing on the river at the time of the dam failure
# dam has an effect on failure
# 0.3605884313583374
# RTE
# .quantities of water that not considered during the construction of the dam
# dam has an effect on construction
# 0.4271688759326935
# RTE
# .the dam site where the river flows onto the Snake River Plain
# dam has an effect on river
# 0.39145419001579285
# RTE
# .the dam site where the river flows onto the Snake River Plain
# dam has an effect on Plain
# 0.32110875844955444
# RTE
# .the dam site where the river flows onto the Snake River Plain
# dam has an effect on Snake
# 0.34658193588256836
# RTE
# .the dam site where the river flows onto the Snake River Plain
# dam has an effect on River
# 0.39815565943717957
# RTE
# .Teton Canyon ends about six miles below the dam site where the river flows onto the Snake River Plain.the dam site where the river flows onto the Snake River Plain
# dam has an effect on mile
# 0.15897652506828308
# RTE
# .One Teton resident drowned.One Teton resident fishing on the river at the time of the dam failure
# dam has an effect on Teton
# 0.48598209023475647
# RTE
# .One Teton resident drowned.One Teton resident fishing on the river at the time of the dam failure
# dam has an effect on resident
# 0.15662865340709686
# RTE
# .One Teton resident fishing on the river at the time of the dam failure
# dam has an effect on river
# 0.3592405915260315
# RTE
# .quantities of water falling that had not been considered during the construction of the dam.quantities of water that not considered during the construction of the dam
# dam has an effect on quantity
# 0.4079323410987854
# RTE
# .quantities of water falling that had not been considered during the construction of the dam.quantities of water that not considered during the construction of the dam
# dam has an effect on water
# 0.5447831749916077
# RTE
# .quantities of water that not considered during the construction of the dam.an extreme flood resulting in quantities of water falling that had not been considered during the construction of the dam
# dam has an effect on quantity
# 0.3565063178539276
# RTE
# .In August 1975 the region experienced an extreme flood resulting in quantities of water falling that had not been considered during the construction of the dam.quantities of water that not considered during the construction of the dam
# dam has an effect on quantity
# 0.4672309160232544
# RTE
# .the dam failed on August 8
# dam has an effect on August
# 0.7858517169952393
# RTE
# .Early on August 8 the dam breached
# dam has an effect on August
# 0.4744590222835541
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# 'labels'
# the dam site where the river flows onto the Snake River Plain
# ['force', 'water', 'sediment', 'stream', 'habitat', 'Snake', 'River', 'tributary', 'Fort', 'Hall', 'bottom']
# The force of the water and excessive sediment also damaged stream habitat in the Snake River and some tributaries as far downstream as the Fort Hall bottoms
# RTE
# .The small agricultural communities of Wilford and Sugar City wiped from the river bank
# river has an effect on bank
# 0.46668243408203125
# RTE
# .The similar community of Teton on the south bank of the river largely spared
# river has an effect on bank
# 0.20206990838050842
# RTE
# .The similar community of Teton on the south bank of the river largely spared
# river has an effect on Teton
# 0.2661495506763458
# RTE
# .The similar community of Teton on the south bank of the river largely spared
# river has an effect on community
# 0.10243930667638779
# RTE
# .tens of thousands of acres of land near the river stripped of fertile topsoil
# river has an effect on acre
# 0.22775885462760925
# RTE
# .tens of thousands of acres of land near the river stripped of fertile topsoil
# river has an effect on land
# 0.6490678787231445
# RTE
# .tens of thousands of acres of land near the river stripped of fertile topsoil
# river has an effect on ten
# 0.043132174760103226
# RTE
# .tens of thousands of acres of land near the river stripped of fertile topsoil
# river has an effect on thousand
# 0.17422346770763397
# RTE
# .the dam site where the river flows onto the Snake River Plain
# river has an effect on site
# 0.24347750842571259
# RTE
# .the dam site where the river flows onto the Snake River Plain
# river has an effect on dam
# 0.1874491423368454
# RTE
# .the dam site where the river flows onto the Snake River Plain
# river has an effect on Plain
# 0.3985741138458252
# RTE
# .the dam site where the river flows onto the Snake River Plain
# river has an effect on Snake
# 0.3606254458427429
# RTE
# .the dam site where the river flows onto the Snake River Plain
# river has an effect on River
# 0.3802206814289093
# RTE
# .Teton Canyon ends about six miles below the dam site where the river flows onto the Snake River Plain.the dam site where the river flows onto the Snake River Plain
# river has an effect on mile
# 0.1378578245639801
# RTE
# .The small agricultural communities of Wilford and Sugar City wiped from the river bank
# river has an effect on Wilford
# 0.43473145365715027
# RTE
# .The small agricultural communities of Wilford and Sugar City wiped from the river bank
# river has an effect on community
# 0.12275659292936325
# RTE
# .The small agricultural communities of Wilford and Sugar City wiped from the river bank
# river has an effect on City
# 0.09153293073177338
# RTE
# .The small agricultural communities of Wilford and Sugar City wiped from the river bank
# river has an effect on Sugar
# 0.22626784443855286
# RTE
# .One Teton resident drowned.One Teton resident fishing on the river at the time of the dam failure
# river has an effect on Teton
# 0.36924830079078674
# RTE
# .One Teton resident drowned.One Teton resident fishing on the river at the time of the dam failure
# river has an effect on resident
# 0.0980154499411583
# RTE
# .One Teton resident fishing on the river at the time of the dam failure
# river has an effect on time
# 0.03621579334139824
# RTE
# .One Teton resident fishing on the river at the time of the dam failure
# river has an effect on failure
# 0.16295410692691803
# RTE
# .One Teton resident fishing on the river at the time of the dam failure
# river has an effect on dam
# 0.1965956836938858
# RTE
# .tens of thousands of acres of land near the river stripped of fertile topsoil
# river has an effect on topsoil
# 0.7618294954299927
# RTE
# .the dam site where the river flows onto the Snake River Plain
# Plain has an effect on Snake
# 0.2460833191871643
# RTE
# .the dam site where the river flows onto the Snake River Plain
# Plain has an effect on River
# 0.1985509991645813
# RTE
# .the dam site where the river flows onto the Snake River Plain
# Plain has an effect on site
# 0.20252162218093872
# RTE
# .the dam site where the river flows onto the Snake River Plain
# Plain has an effect on dam
# 0.133014515042305
# RTE
# .the dam site where the river flows onto the Snake River Plain
# Plain has an effect on river
# 0.19850318133831024
# RTE
# .Teton Canyon ends about six miles below the dam site where the river flows onto the Snake River Plain.the dam site where the river flows onto the Snake River Plain
# Plain has an effect on mile
# 0.06643705815076828

# %%
KG.nodes()
# Out:
# NodeView((('failure', 'noun'), ('flood', 'noun'), ('habitat', 'noun'), ('force', 'noun'), ('tributary', 'noun'), ('River', 'noun'), ('city', 'noun'), ('lumber', 'noun'), ('Snake', 'noun'), ('fire', 'noun'), ('gasoline', 'noun'), ('water', 'noun'), ('home', 'noun'), ('business', 'noun'), ('town', 'noun'), ('quantity', 'noun'), ('yard', 'noun'), ('racing', 'noun'), ('tank', 'noun'), ('storage', 'noun'), ('bottom', 'noun'), ('stream', 'noun'), ('river', 'noun'), ('part', 'noun'), ('Teton', 'noun'), ('wall', 'noun'), ('zone', 'noun'), ('dozen', 'noun'), ('Fort', 'noun'), ('floodwater', 'noun'), ('account', 'noun'), ('Hall', 'noun'), ('log', 'noun'), ('ten', 'noun'), ('topsoil', 'noun'), ('thousand', 'noun'), ('sediment', 'noun')))

# %%
nx.write_graphml(KG, 'Teton.gml',named_key_ids=True)

# %%
getRTE2('the eleven deaths attributed to the flood','the flood impacted to the eleven deaths')
# Out:
# 'BertTokenizer' object has no attribute 'encode'
# 1

# %%
start_node = ('log', 'noun')
G_ego = nx.ego_graph(KG, start_node ,1)
#drawKG(G_ego)
drawgraph(G_ego)
# Out:
# ---------------------------------------------------------------------------
# NodeNotFound                              Traceback (most recent call last)
# /var/folders/yz/rx8w6djd42n7bczthnwpl9_40000gn/T/ipykernel_20751/3018906605.py in <module>
#       1 start_node = ('log', 'noun')
# ----> 2 G_ego = nx.ego_graph(KG, start_node ,1)
#       3 #drawKG(G_ego)
#       4 drawgraph(G_ego)
#
# /Library/Python/3.7/site-packages/networkx/generators/ego.py in ego_graph(G, n, radius, center, undirected, distance)
#      57             sp, _ = nx.single_source_dijkstra(G, n, cutoff=radius, weight=distance)
#      58         else:
# ---> 59             sp = dict(nx.single_source_shortest_path_length(G, n, cutoff=radius))
#      60
#      61     H = G.subgraph(sp).copy()
#
# /Library/Python/3.7/site-packages/networkx/algorithms/shortest_paths/unweighted.py in single_source_shortest_path_length(G, source, cutoff)
#      53     """
#      54     if source not in G:
# ---> 55         raise nx.NodeNotFound(f"Source {source} is not in G")
#      56     if cutoff is None:
#      57         cutoff = float("inf")
#
# NodeNotFound: Source ('log', 'noun') is not in G

# %%
for e in ref_KG.edges(data=True):
    if e[0][0] == 'city':
        print(e)

# %%
ref_KG = nx.Graph()
nodes = []
all_nodes = KG.nodes()
for ref in all_nodes:
    print('object')
    print(ref)
    for n in KG.edges(data=True):
        if (n[1] == ref and n[2]['label'] == 'has_effect_on'): 
           print('susc')
           print(n)
           n_s = n[0]
           s_node = (n_s[0],n_s[1],'susc')
           print(s_node)
           ref_node = (ref[0],ref[1],'object')
           ref_KG.add_edge(s_node,ref_node, weight = 1)
           for n_e in all_nodes:
                if n_e != ref and n_e != n_s:
                    risk_node = (n_e[0],n_e[1],'risk')
                    if nx.has_path(KG, n_e,n_s):
                         ref_KG.add_edge(risk_node,s_node, weight = 1)
# Out:
# object
# ('flood', 'noun')
# object
# ('Wilford', 'noun')
# susc
# (('flood', 'noun'), ('Wilford', 'noun'), {'weight': 0.8908891081809998, 'label': 'has_effect_on'})
# ('flood', 'noun', 'susc')
# object
# ('Roberts', 'noun')
# susc
# (('flood', 'noun'), ('Roberts', 'noun'), {'weight': 0.9502467513084412, 'label': 'has_effect_on'})
# ('flood', 'noun', 'susc')
# susc
# (('water', 'noun'), ('Roberts', 'noun'), {'weight': 0.912716269493103, 'label': 'has_effect_on'})
# ('water', 'noun', 'susc')
# object
# ('thousand', 'noun')
# object
# ('town', 'noun')
# susc
# (('thousand', 'noun'), ('town', 'noun'), {'weight': 0.8075220584869385, 'label': 'has_effect_on'})
# ('thousand', 'noun', 'susc')
# object
# ('topsoil', 'noun')
# susc
# (('thousand', 'noun'), ('topsoil', 'noun'), {'weight': 0.8410375714302063, 'label': 'has_effect_on'})
# ('thousand', 'noun', 'susc')
# object
# ('failure', 'noun')
# object
# ('Teton', 'noun')
# susc
# (('failure', 'noun'), ('Teton', 'noun'), {'weight': 0.8556009531021118, 'label': 'has_effect_on'})
# ('failure', 'noun', 'susc')
# susc
# (('force', 'noun'), ('Teton', 'noun'), {'weight': 0.8556603789329529, 'label': 'has_effect_on'})
# ('force', 'noun', 'susc')
# object
# ('River', 'noun')
# susc
# (('failure', 'noun'), ('River', 'noun'), {'weight': 0.8260191082954407, 'label': 'has_effect_on'})
# ('failure', 'noun', 'susc')
# susc
# (('force', 'noun'), ('River', 'noun'), {'weight': 0.8842409253120422, 'label': 'has_effect_on'})
# ('force', 'noun', 'susc')
# object
# ('water', 'noun')
# susc
# (('tributary', 'noun'), ('water', 'noun'), {'weight': 0.8417326211929321, 'label': 'has_effect_on'})
# ('tributary', 'noun', 'susc')
# object
# ('habitat', 'noun')
# susc
# (('water', 'noun'), ('habitat', 'noun'), {'weight': 0.9125840067863464, 'label': 'has_effect_on'})
# ('water', 'noun', 'susc')
# susc
# (('force', 'noun'), ('habitat', 'noun'), {'weight': 0.940265953540802, 'label': 'has_effect_on'})
# ('force', 'noun', 'susc')
# susc
# (('sediment', 'noun'), ('habitat', 'noun'), {'weight': 0.9333377480506897, 'label': 'has_effect_on'})
# ('sediment', 'noun', 'susc')
# object
# ('Snake', 'noun')
# susc
# (('water', 'noun'), ('Snake', 'noun'), {'weight': 0.8190962672233582, 'label': 'has_effect_on'})
# ('water', 'noun', 'susc')
# susc
# (('force', 'noun'), ('Snake', 'noun'), {'weight': 0.880916178226471, 'label': 'has_effect_on'})
# ('force', 'noun', 'susc')
# susc
# (('sediment', 'noun'), ('Snake', 'noun'), {'weight': 0.8538298606872559, 'label': 'has_effect_on'})
# ('sediment', 'noun', 'susc')
# object
# ('stream', 'noun')
# susc
# (('water', 'noun'), ('stream', 'noun'), {'weight': 0.8675554394721985, 'label': 'has_effect_on'})
# ('water', 'noun', 'susc')
# susc
# (('force', 'noun'), ('stream', 'noun'), {'weight': 0.8998088836669922, 'label': 'has_effect_on'})
# ('force', 'noun', 'susc')
# susc
# (('sediment', 'noun'), ('stream', 'noun'), {'weight': 0.8256036639213562, 'label': 'has_effect_on'})
# ('sediment', 'noun', 'susc')
# object
# ('tributary', 'noun')
# susc
# (('water', 'noun'), ('tributary', 'noun'), {'weight': 0.8692893385887146, 'label': 'has_effect_on'})
# ('water', 'noun', 'susc')
# susc
# (('force', 'noun'), ('tributary', 'noun'), {'weight': 0.9149293899536133, 'label': 'has_effect_on'})
# ('force', 'noun', 'susc')
# susc
# (('sediment', 'noun'), ('tributary', 'noun'), {'weight': 0.8493481874465942, 'label': 'has_effect_on'})
# ('sediment', 'noun', 'susc')
# object
# ('log', 'noun')
# object
# ('lumber', 'noun')
# susc
# (('log', 'noun'), ('lumber', 'noun'), {'weight': 0.8087524175643921, 'label': 'has_effect_on'})
# ('log', 'noun', 'susc')
# susc
# (('force', 'noun'), ('lumber', 'noun'), {'weight': 0.840306282043457, 'label': 'has_effect_on'})
# ('force', 'noun', 'susc')
# object
# ('dozen', 'noun')
# object
# ('storage', 'noun')
# susc
# (('dozen', 'noun'), ('storage', 'noun'), {'weight': 0.8594290018081665, 'label': 'has_effect_on'})
# ('dozen', 'noun', 'susc')
# object
# ('gasoline', 'noun')
# susc
# (('dozen', 'noun'), ('gasoline', 'noun'), {'weight': 0.887032687664032, 'label': 'has_effect_on'})
# ('dozen', 'noun', 'susc')
# susc
# (('fire', 'noun'), ('gasoline', 'noun'), {'weight': 0.8896347284317017, 'label': 'has_effect_on'})
# ('fire', 'noun', 'susc')
# object
# ('tank', 'noun')
# susc
# (('dozen', 'noun'), ('tank', 'noun'), {'weight': 0.8670128583908081, 'label': 'has_effect_on'})
# ('dozen', 'noun', 'susc')
# object
# ('fire', 'noun')
# susc
# (('lumber', 'noun'), ('fire', 'noun'), {'weight': 0.868682324886322, 'label': 'has_effect_on'})
# ('lumber', 'noun', 'susc')
# susc
# (('gasoline', 'noun'), ('fire', 'noun'), {'weight': 0.9933587908744812, 'label': 'has_effect_on'})
# ('gasoline', 'noun', 'susc')
# object
# ('city', 'noun')
# susc
# (('fire', 'noun'), ('city', 'noun'), {'weight': 0.8489618897438049, 'label': 'has_effect_on'})
# ('fire', 'noun', 'susc')
# susc
# (('force', 'noun'), ('city', 'noun'), {'weight': 0.8109039664268494, 'label': 'has_effect_on'})
# ('force', 'noun', 'susc')
# object
# ('force', 'noun')
# susc
# (('part', 'noun'), ('force', 'noun'), {'weight': 0.813083291053772, 'label': 'has_effect_on'})
# ('part', 'noun', 'susc')
# object
# ('engineer', 'noun')
# object
# ('discharge', 'noun')
# susc
# (('engineer', 'noun'), ('discharge', 'noun'), {'weight': 0.8486176133155823, 'label': 'has_effect_on'})
# ('engineer', 'noun', 'susc')
# object
# ('zone', 'noun')
# object
# ('canyon', 'noun')
# susc
# (('zone', 'noun'), ('canyon', 'noun'), {'weight': 0.8461983799934387, 'label': 'has_effect_on'})
# ('zone', 'noun', 'susc')
# susc
# (('wall', 'noun'), ('canyon', 'noun'), {'weight': 0.8235072493553162, 'label': 'has_effect_on'})
# ('wall', 'noun', 'susc')
# object
# ('wall', 'noun')
# susc
# (('zone', 'noun'), ('wall', 'noun'), {'weight': 0.8282636404037476, 'label': 'has_effect_on'})
# ('zone', 'noun', 'susc')
# object
# ('part', 'noun')
# object
# ('sediment', 'noun')
# object
# ('turbine', 'noun')
# object
# ('hall', 'noun')
# susc
# (('turbine', 'noun'), ('hall', 'noun'), {'weight': 0.8847077488899231, 'label': 'has_effect_on'})
# ('turbine', 'noun', 'susc')
# object
# ('ceiling', 'noun')
# susc
# (('turbine', 'noun'), ('ceiling', 'noun'), {'weight': 0.8925342559814453, 'label': 'has_effect_on'})
# ('turbine', 'noun', 'susc')
# object
# ('point', 'noun')
# object
# ('power', 'noun')
# susc
# (('point', 'noun'), ('power', 'noun'), {'weight': 0.8794193863868713, 'label': 'has_effect_on'})
# ('point', 'noun', 'susc')
# susc
# (('station', 'noun'), ('power', 'noun'), {'weight': 0.8322134017944336, 'label': 'has_effect_on'})
# ('station', 'noun', 'susc')
# object
# ('station', 'noun')
# object
# ('spillway', 'noun')
# object
# ('damage', 'noun')
# susc
# (('spillway', 'noun'), ('damage', 'noun'), {'weight': 0.9140458106994629, 'label': 'has_effect_on'})
# ('spillway', 'noun', 'susc')

# %%
ret_arr = []
for n in ref_KG.edges():
    if n[0][2] == 'susc':
        ret_arr = ret_arr + [[n[0][0],n[0][1], n[0][2],n[1][0],n[1][1], n[1][2]]]
pd.DataFrame(ret_arr, columns = ['s_word','s_type','s_role','t_word','t_type','t_role']).to_csv("susc_rel.csv",sep="|", header=True,index=False)

ret_arr = []
for n in ref_KG.edges():
    if n[0][2] == 'risk':
        ret_arr = ret_arr + [[n[0][0],n[0][1], n[0][2],n[1][0],n[1][1], n[1][2]]]
pd.DataFrame(ret_arr, columns = ['s_word','s_type','s_role','t_word','t_type','t_role']).to_csv("risk_rel.csv",sep="|", header=True,index=False)

# %%
for e in ref_KG.edges():
    print(e)
# Out:
# (('flood', 'noun', 'susc'), ('Wilford', 'noun', 'object'))
# (('flood', 'noun', 'susc'), ('Roberts', 'noun', 'object'))
# (('Roberts', 'noun', 'object'), ('water', 'noun', 'susc'))
# (('water', 'noun', 'susc'), ('tributary', 'noun', 'risk'))
# (('water', 'noun', 'susc'), ('force', 'noun', 'risk'))
# (('water', 'noun', 'susc'), ('part', 'noun', 'risk'))
# (('water', 'noun', 'susc'), ('sediment', 'noun', 'risk'))
# (('water', 'noun', 'susc'), ('habitat', 'noun', 'object'))
# (('water', 'noun', 'susc'), ('Snake', 'noun', 'object'))
# (('water', 'noun', 'susc'), ('stream', 'noun', 'object'))
# (('water', 'noun', 'susc'), ('tributary', 'noun', 'object'))
# (('force', 'noun', 'risk'), ('tributary', 'noun', 'susc'))
# (('force', 'noun', 'risk'), ('fire', 'noun', 'susc'))
# (('force', 'noun', 'risk'), ('lumber', 'noun', 'susc'))
# (('force', 'noun', 'risk'), ('gasoline', 'noun', 'susc'))
# (('part', 'noun', 'risk'), ('force', 'noun', 'susc'))
# (('part', 'noun', 'risk'), ('tributary', 'noun', 'susc'))
# (('part', 'noun', 'risk'), ('fire', 'noun', 'susc'))
# (('part', 'noun', 'risk'), ('lumber', 'noun', 'susc'))
# (('part', 'noun', 'risk'), ('gasoline', 'noun', 'susc'))
# (('sediment', 'noun', 'risk'), ('tributary', 'noun', 'susc'))
# (('thousand', 'noun', 'susc'), ('town', 'noun', 'object'))
# (('thousand', 'noun', 'susc'), ('topsoil', 'noun', 'object'))
# (('failure', 'noun', 'susc'), ('Teton', 'noun', 'object'))
# (('failure', 'noun', 'susc'), ('River', 'noun', 'object'))
# (('Teton', 'noun', 'object'), ('force', 'noun', 'susc'))
# (('force', 'noun', 'susc'), ('River', 'noun', 'object'))
# (('force', 'noun', 'susc'), ('habitat', 'noun', 'object'))
# (('force', 'noun', 'susc'), ('Snake', 'noun', 'object'))
# (('force', 'noun', 'susc'), ('stream', 'noun', 'object'))
# (('force', 'noun', 'susc'), ('tributary', 'noun', 'object'))
# (('force', 'noun', 'susc'), ('lumber', 'noun', 'object'))
# (('force', 'noun', 'susc'), ('city', 'noun', 'object'))
# (('tributary', 'noun', 'susc'), ('water', 'noun', 'object'))
# (('habitat', 'noun', 'object'), ('sediment', 'noun', 'susc'))
# (('sediment', 'noun', 'susc'), ('Snake', 'noun', 'object'))
# (('sediment', 'noun', 'susc'), ('stream', 'noun', 'object'))
# (('sediment', 'noun', 'susc'), ('tributary', 'noun', 'object'))
# (('log', 'noun', 'susc'), ('lumber', 'noun', 'object'))
# (('dozen', 'noun', 'susc'), ('storage', 'noun', 'object'))
# (('dozen', 'noun', 'susc'), ('gasoline', 'noun', 'object'))
# (('dozen', 'noun', 'susc'), ('tank', 'noun', 'object'))
# (('gasoline', 'noun', 'object'), ('fire', 'noun', 'susc'))
# (('fire', 'noun', 'susc'), ('log', 'noun', 'risk'))
# (('fire', 'noun', 'susc'), ('lumber', 'noun', 'risk'))
# (('fire', 'noun', 'susc'), ('dozen', 'noun', 'risk'))
# (('fire', 'noun', 'susc'), ('city', 'noun', 'object'))
# (('fire', 'noun', 'susc'), ('gasoline', 'noun', 'risk'))
# (('log', 'noun', 'risk'), ('lumber', 'noun', 'susc'))
# (('log', 'noun', 'risk'), ('gasoline', 'noun', 'susc'))
# (('lumber', 'noun', 'risk'), ('gasoline', 'noun', 'susc'))
# (('dozen', 'noun', 'risk'), ('gasoline', 'noun', 'susc'))
# (('lumber', 'noun', 'susc'), ('fire', 'noun', 'object'))
# (('fire', 'noun', 'object'), ('gasoline', 'noun', 'susc'))
# (('part', 'noun', 'susc'), ('force', 'noun', 'object'))
# (('engineer', 'noun', 'susc'), ('discharge', 'noun', 'object'))
# (('zone', 'noun', 'susc'), ('canyon', 'noun', 'object'))
# (('zone', 'noun', 'susc'), ('wall', 'noun', 'object'))
# (('canyon', 'noun', 'object'), ('wall', 'noun', 'susc'))
# (('wall', 'noun', 'susc'), ('zone', 'noun', 'risk'))
# (('turbine', 'noun', 'susc'), ('hall', 'noun', 'object'))
# (('turbine', 'noun', 'susc'), ('ceiling', 'noun', 'object'))
# (('point', 'noun', 'susc'), ('power', 'noun', 'object'))
# (('power', 'noun', 'object'), ('station', 'noun', 'susc'))
# (('spillway', 'noun', 'susc'), ('damage', 'noun', 'object'))

# %%
start_node = ('city', 'noun','object')
G_ego = nx.ego_graph(ref_KG, start_node ,2)
#drawKG(G_ego
drawgraph(G_ego)

# %%
drawgraph(ref_KG)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes() if n[2] == 'susc']
    plt.hist(degrees, bins = 50)
    plt.show()
    return degrees

degs = plot_degree_dist(ref_KG)

# %%
t = [n for n in ref_KG.nodes() if n[2] == 'susc']

# %%
t = [n for n in ref_KG.nodes() if n[2] == 'object']

# %%
t = [n for n in ref_KG.nodes() if n[2] == 'risk']

# %%
len(t)
# Out:
# 40

# %%
t = [n for n in ref_KG.nodes() if n[2] == 'risk']

# %%
ref_KG.remove_nodes_from(list(nx.isolates(ref_KG)))

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

G = nx.gnp_random_graph(100, 0.02, seed=10374196)

degree_sequence = sorted((d for n, d in ref_KG.degree() if n[2] == 'susc'), reverse=True)
dmax = max(degree_sequence)

fig = plt.figure("Degree of a random graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax1 = fig.add_subplot(axgrid[3:, :2])
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

fig.tight_layout()
plt.show()

# %%
from networkx.algorithms import tournament
ref_node = ('city', 'noun','object')
for n in ref_KG.edges(data=True):
    if (n[1] == ref_node): 
      print(n)
# Out:
# (('force', 'noun', 'susc'), ('city', 'noun', 'object'), {'weight': 1})
# (('log', 'noun', 'susc'), ('city', 'noun', 'object'), {'weight': 1})
# (('fire', 'noun', 'susc'), ('city', 'noun', 'object'), {'weight': 1})

# %%
for n_e in s_nodes:
            if n_e != ref_node:
                if nx.has_path(KG, n_e,ref_node):
                    print(n_e)
# Out:
# ('dam', 'noun')
# ('Rexburg', 'noun')
# ('district', 'noun')
# ('north', 'noun')
# ('failure', 'noun')
# ('force', 'noun')
# ('zone', 'noun')
# ('wall', 'noun')
# ('River', 'noun')
# ('Snake', 'noun')
# ('Plain', 'noun')
# ('part', 'noun')
# ('river', 'noun')
# ('Teton', 'noun')
# ('flood', 'noun')
# ('water', 'noun')
# ('mile', 'noun')
# ('quantity', 'noun')
# ('Wilford', 'noun')
# ('terminus', 'noun')
# ('community', 'noun')
# ('Hibbard', 'noun')
# ('Roberts', 'noun')
# ('side', 'noun')
# ('Sugar', 'noun')
# ('Salem', 'noun')
# ('canyon', 'noun')
# ('result', 'noun')
# ('famine', 'noun')
# ('epidemic', 'noun')
# ('City', 'noun')
# ('death', 'noun')
# ('time', 'noun')
# ('woman', 'noun')
# ('log', 'noun')
# ('fire', 'noun')
# ('habitat', 'noun')
# ('tributary', 'noun')
# ('Fork', 'noun')
# ('Menan', 'noun')
# ('Buttes', 'noun')
# ('Henrys', 'noun')
# ('route', 'noun')
# ('stream', 'noun')
# ('sediment', 'noun')
# ('Fort', 'noun')
# ('bottom', 'noun')
# ('Hall', 'noun')

# %%
start_node = ('log', 'noun', 'risk')
G_ego = nx.ego_graph(ref_KG, start_node ,3)
drawgraph(G_ego)
